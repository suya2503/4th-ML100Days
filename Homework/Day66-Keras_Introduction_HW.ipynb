# %% [markdown]
# # 作業目標:
#     檢查 backend
#     檢查 fuzz factor
#     設定 Keras 浮點運算為float16

# %%
import keras
from keras import backend as K

# %% [markdown]
# # fuzz factor
#
# 數值表達式中使用的模糊因子。
# 此功能是一組Keras後端功能的一部分，可以對後端張量引擎（例如TensorFlow，CNTK，Theano等）的核心操作進行更低級別的訪問。

# %%
print(keras.__version__)
# Out:
# 2.4.3

# %%
#  GPU加速测试, True - Windows用戶得到True也沒有關係，因為Anaconda中已經內置了MKL加速庫
import numpy 
id(numpy.dot) == id(numpy.core.multiarray.dot)
# Out:
# True

# %%
#檢查Keras float 
K.floatx()
# Out:
# 'float32'

# %%
# 設定浮點數運算為float16
K.set_floatx('float16')
K.floatx()
# Out:
# 'float16'

# %% [markdown]
# ### 切換backend
#
# * 可以直接到C:\Users\user\.keras的keras.json查看目前的backend
# ![image.png](attachment:91804b27-6e92-4a15-9807-3187d0f2a08c.png)
#
# * 亦可以用K.backend()檢查現在的backend

# %%
K.backend()
# Out:
# 'tensorflow'
